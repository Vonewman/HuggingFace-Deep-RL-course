# %% [markdown]
# <a href="https://colab.research.google.com/github/Vonewman/HuggingFace-Deep-RL-course/blob/main/Train_Huggy_the_Dog_%F0%9F%90%B6_to_fetch_a_stick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bonus Unit 1: Let's train Huggy the Dog 🐶 to fetch a stick

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit2/thumbnail.png" alt="Bonus Unit 1Thumbnail">
#
# In this notebook, we'll reinforce what we learned in the first Unit by **teaching Huggy the Dog to fetch the stick and then play with it directly in your browser**
#
# ⬇️ Here is an example of what **you will achieve at the end of the unit.** ⬇️ (launch ▶ to see)

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - Huggy the Dog, an environment created by [Thomas Simonini](https://twitter.com/ThomasSimonini) based on [Puppo The Corgi](https://blog.unity.com/technology/puppo-the-corgi-cuteness-overload-with-the-unity-ml-agents-toolkit)
#
# ### The library used 📚
#
# - [MLAgents (Hugging Face version)](https://github.com/huggingface/ml-agents)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Understand **the state space, action space and reward function used to train Huggy**.
# - **Train your own Huggy** to fetch the stick.
# - Be able to play **with your trained Huggy directly in your browser**.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# ## Clone the repository and install the dependencies 🔽
#
# - We need to clone the repository, that **contains the experimental version of the library that allows you to push your trained agent to the Hub.**

# %%
# %%capture
# Clone this specific repository (can take 3min)
# !git clone https://github.com/huggingface/ml-agents/

# %%
# %%capture
# Go inside the repository and install the package (can take 3min)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ## Download and move the environment zip file in `./trained-envs-executables/linux/`
#
# - Our environment executable is in a zip file.
# - We need to download it and place it to `./trained-envs-executables/linux/`

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF" -O ./trained-envs-executables/linux/Huggy.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-01-18 13:31:30--  https://docs.google.com/uc?export=download&confirm=t&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF
# Resolving docs.google.com (docs.google.com)... 142.251.10.100, 142.251.10.138, 142.251.10.102, ...
# Connecting to docs.google.com (docs.google.com)|142.251.10.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/h3rhc12h4eojmb33k0r7r2fcup3aidjk/1674048675000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=7978ce1f-8a9f-4a8f-89e3-9657cf4c547a [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-18 13:31:31--  https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/h3rhc12h4eojmb33k0r7r2fcup3aidjk/1674048675000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=7978ce1f-8a9f-4a8f-89e3-9657cf4c547a
# Resolving doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)... 74.125.24.132, 2404:6800:4003:c03::84
# Connecting to doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)|74.125.24.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/x-zip-compressed]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M   160MB/s    in 0.2s
#
# 2023-01-18 13:31:31 (160 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %% [markdown]
# Download the file Huggy.zip from https://drive.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF using `wget`. Check out the full solution to download large files from GDrive [here](https://bcrf.biochem.wisc.edu/2021/02/05/download-google-drive-files-using-wget/)

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %% [markdown]
# Make sure your file is accessible

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %% [markdown]
# ## Let's recap how this environment works
#
# ### The State Space: what Huggy "perceives."
#
# Huggy doesn't "see" his environment. Instead, we provide him information about the environment:
#
# - The target (stick) position
# - The relative position between himself and the target
# - The orientation of his legs.
#
# Given all this information, Huggy **can decide which action to take next to fulfill his goal**.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy.jpg" alt="Huggy" width="100%">
#
# ### The Action Space: what moves Huggy can do
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/huggy-action.jpg" alt="Huggy action" width="100%">
#
# **Joint motors drive huggy legs**. It means that to get the target, Huggy needs to **learn to rotate the joint motors of each of his legs correctly so he can move**.
#
# ### The Reward Function
#
# The reward function is designed so that **Huggy will fulfill his goal** : fetch the stick.
#
# Remember that one of the foundations of Reinforcement Learning is the *reward hypothesis*: a goal can be described as the **maximization of the expected cumulative reward**.
#
# Here, our goal is that Huggy **goes towards the stick but without spinning too much**. Hence, our reward function must translate this goal.
#
# Our reward function:
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/reward.jpg" alt="Huggy reward function" width="100%">
#
# - *Orientation bonus*: we **reward him for getting close to the target**.
# - *Time penalty*: a fixed-time penalty given at every action to **force him to get to the stick as fast as possible**.
# - *Rotation penalty*: we penalize Huggy if **he spins too much and turns too quickly**.
# - *Getting to the target reward*: we reward Huggy for **reaching the target**.

# %% [markdown]
# ## Check the Huggy config file
#
# - In ML-Agents, you define the **training hyperparameters into config.yaml files.**
#
# - For the scope of this notebook, we're not going to modify the hyperparameters, but if you want to try as an experiment, you should also try to modify some other hyperparameters, Unity provides very [good documentation explaining each of them here](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md).

# %% [markdown]
# - **In the case you want to modify the hyperparameters**, in Google Colab notebook, you can click here to open the config.yaml: `/content/ml-agents/config/ppo/Huggy.yaml`
#
# - For instance **if you want to save more models during the training** (for now, we save every 200,000 training timesteps). You need to modify:
#   - `checkpoint_interval`: The number of training timesteps collected between each checkpoint.
#   - `keep_checkpoints`: The maximum number of model checkpoints to keep.
#
# => Just keep in mind that **decreasing the `checkpoint_interval` means more models to upload to the Hub and so a longer uploading time**
# We’re now ready to train our agent 🔥.

# %% [markdown]
# ## Train our agent
#
# To train our agent, we just need to **launch mlagents-learn and select the executable containing the environment.**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/mllearn.png" alt="ml learn function" width="100%">
#
# With ML Agents, we run a training script. We define four parameters:
#
# 1. `mlagents-learn <config>`: the path where the hyperparameter config file is.
# 2. `--env`: where the environment executable is.
# 3. `--run_id`: the name you want to give to your training run id.
# 4. `--no-graphics`: to not launch the visualization during the training.
#
# Train the model and use the `--resume` flag to continue training in case of interruption.
#
# > It will fail first time when you use `--resume`, try running the block again to bypass the error.

# %% [markdown]
# The training will take 30 to 45min depending on your machine (don't forget to **set up a GPU**), go take a ☕️you deserve it 🤗.

# %%
# !mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	checkpoint_interval:	200000
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# INFO:mlagents.trainers.stats:Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	checkpoint_interval:	200000
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 65.242 s. Mean Reward: 1.844. Std of Reward: 0.829. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 50000. Time Elapsed: 65.242 s. Mean Reward: 1.844. Std of Reward: 0.829. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 115.270 s. Mean Reward: 2.614. Std of Reward: 1.033. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 100000. Time Elapsed: 115.270 s. Mean Reward: 2.614. Std of Reward: 1.033. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 169.921 s. Mean Reward: 2.941. Std of Reward: 1.226. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 150000. Time Elapsed: 169.921 s. Mean Reward: 2.941. Std of Reward: 1.226. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 221.034 s. Mean Reward: 3.280. Std of Reward: 1.363. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 200000. Time Elapsed: 221.034 s. Mean Reward: 3.280. Std of Reward: 1.363. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-199979.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-199979.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 275.651 s. Mean Reward: 3.634. Std of Reward: 1.448. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 250000. Time Elapsed: 275.651 s. Mean Reward: 3.634. Std of Reward: 1.448. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 328.019 s. Mean Reward: 3.564. Std of Reward: 1.615. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 300000. Time Elapsed: 328.019 s. Mean Reward: 3.564. Std of Reward: 1.615. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 379.336 s. Mean Reward: 3.749. Std of Reward: 1.782. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 350000. Time Elapsed: 379.336 s. Mean Reward: 3.749. Std of Reward: 1.782. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 433.665 s. Mean Reward: 3.752. Std of Reward: 1.804. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 400000. Time Elapsed: 433.665 s. Mean Reward: 3.752. Std of Reward: 1.804. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-399986.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-399986.onnx
# [INFO] Huggy. Step: 450000. Time Elapsed: 487.232 s. Mean Reward: 3.593. Std of Reward: 1.724. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 450000. Time Elapsed: 487.232 s. Mean Reward: 3.593. Std of Reward: 1.724. Training.
# [INFO] Huggy. Step: 500000. Time Elapsed: 541.682 s. Mean Reward: 3.909. Std of Reward: 1.840. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 500000. Time Elapsed: 541.682 s. Mean Reward: 3.909. Std of Reward: 1.840. Training.
# [INFO] Huggy. Step: 550000. Time Elapsed: 595.525 s. Mean Reward: 3.753. Std of Reward: 1.800. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 550000. Time Elapsed: 595.525 s. Mean Reward: 3.753. Std of Reward: 1.800. Training.
# [INFO] Huggy. Step: 600000. Time Elapsed: 650.991 s. Mean Reward: 3.809. Std of Reward: 1.809. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 600000. Time Elapsed: 650.991 s. Mean Reward: 3.809. Std of Reward: 1.809. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-599969.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-599969.onnx
# [INFO] Huggy. Step: 650000. Time Elapsed: 702.486 s. Mean Reward: 3.865. Std of Reward: 1.737. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 650000. Time Elapsed: 702.486 s. Mean Reward: 3.865. Std of Reward: 1.737. Training.
# [INFO] Huggy. Step: 700000. Time Elapsed: 754.868 s. Mean Reward: 3.844. Std of Reward: 1.799. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 700000. Time Elapsed: 754.868 s. Mean Reward: 3.844. Std of Reward: 1.799. Training.
# [INFO] Huggy. Step: 750000. Time Elapsed: 810.187 s. Mean Reward: 3.721. Std of Reward: 1.708. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 750000. Time Elapsed: 810.187 s. Mean Reward: 3.721. Std of Reward: 1.708. Training.
# [INFO] Huggy. Step: 800000. Time Elapsed: 863.213 s. Mean Reward: 3.844. Std of Reward: 1.726. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 800000. Time Elapsed: 863.213 s. Mean Reward: 3.844. Std of Reward: 1.726. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-799912.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-799912.onnx
# [INFO] Huggy. Step: 850000. Time Elapsed: 919.132 s. Mean Reward: 3.713. Std of Reward: 1.777. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 850000. Time Elapsed: 919.132 s. Mean Reward: 3.713. Std of Reward: 1.777. Training.
# [INFO] Huggy. Step: 900000. Time Elapsed: 971.638 s. Mean Reward: 3.807. Std of Reward: 1.901. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 900000. Time Elapsed: 971.638 s. Mean Reward: 3.807. Std of Reward: 1.901. Training.
# [INFO] Huggy. Step: 950000. Time Elapsed: 1027.245 s. Mean Reward: 3.739. Std of Reward: 1.727. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 950000. Time Elapsed: 1027.245 s. Mean Reward: 3.739. Std of Reward: 1.727. Training.
# [INFO] Huggy. Step: 1000000. Time Elapsed: 1079.412 s. Mean Reward: 3.724. Std of Reward: 1.803. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1000000. Time Elapsed: 1079.412 s. Mean Reward: 3.724. Std of Reward: 1.803. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-999928.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-999928.onnx
# [INFO] Huggy. Step: 1050000. Time Elapsed: 1132.779 s. Mean Reward: 3.898. Std of Reward: 1.763. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1050000. Time Elapsed: 1132.779 s. Mean Reward: 3.898. Std of Reward: 1.763. Training.
# [INFO] Huggy. Step: 1100000. Time Elapsed: 1189.119 s. Mean Reward: 3.715. Std of Reward: 1.859. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1100000. Time Elapsed: 1189.119 s. Mean Reward: 3.715. Std of Reward: 1.859. Training.
# [INFO] Huggy. Step: 1150000. Time Elapsed: 1241.930 s. Mean Reward: 3.764. Std of Reward: 1.842. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1150000. Time Elapsed: 1241.930 s. Mean Reward: 3.764. Std of Reward: 1.842. Training.
# [INFO] Huggy. Step: 1200000. Time Elapsed: 1297.609 s. Mean Reward: 3.883. Std of Reward: 1.835. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1200000. Time Elapsed: 1297.609 s. Mean Reward: 3.883. Std of Reward: 1.835. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1199984.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1199984.onnx
# [INFO] Huggy. Step: 1250000. Time Elapsed: 1349.369 s. Mean Reward: 3.886. Std of Reward: 1.752. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1250000. Time Elapsed: 1349.369 s. Mean Reward: 3.886. Std of Reward: 1.752. Training.
# [INFO] Huggy. Step: 1300000. Time Elapsed: 1407.075 s. Mean Reward: 3.934. Std of Reward: 1.798. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1300000. Time Elapsed: 1407.075 s. Mean Reward: 3.934. Std of Reward: 1.798. Training.
# [INFO] Huggy. Step: 1350000. Time Elapsed: 1458.941 s. Mean Reward: 3.842. Std of Reward: 1.838. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1350000. Time Elapsed: 1458.941 s. Mean Reward: 3.842. Std of Reward: 1.838. Training.
# [INFO] Huggy. Step: 1400000. Time Elapsed: 1511.358 s. Mean Reward: 3.817. Std of Reward: 1.807. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1400000. Time Elapsed: 1511.358 s. Mean Reward: 3.817. Std of Reward: 1.807. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1399916.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1399916.onnx
# [INFO] Huggy. Step: 1450000. Time Elapsed: 1567.204 s. Mean Reward: 3.836. Std of Reward: 1.824. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1450000. Time Elapsed: 1567.204 s. Mean Reward: 3.836. Std of Reward: 1.824. Training.
# [INFO] Huggy. Step: 1500000. Time Elapsed: 1621.045 s. Mean Reward: 3.807. Std of Reward: 1.762. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1500000. Time Elapsed: 1621.045 s. Mean Reward: 3.807. Std of Reward: 1.762. Training.
# [INFO] Huggy. Step: 1550000. Time Elapsed: 1676.000 s. Mean Reward: 3.952. Std of Reward: 1.816. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1550000. Time Elapsed: 1676.000 s. Mean Reward: 3.952. Std of Reward: 1.816. Training.
# [INFO] Huggy. Step: 1600000. Time Elapsed: 1727.761 s. Mean Reward: 3.788. Std of Reward: 1.795. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1600000. Time Elapsed: 1727.761 s. Mean Reward: 3.788. Std of Reward: 1.795. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1599997.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1599997.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 1784.521 s. Mean Reward: 3.993. Std of Reward: 1.830. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1650000. Time Elapsed: 1784.521 s. Mean Reward: 3.993. Std of Reward: 1.830. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 1836.667 s. Mean Reward: 3.797. Std of Reward: 1.753. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1700000. Time Elapsed: 1836.667 s. Mean Reward: 3.797. Std of Reward: 1.753. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 1889.454 s. Mean Reward: 3.822. Std of Reward: 1.730. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1750000. Time Elapsed: 1889.454 s. Mean Reward: 3.822. Std of Reward: 1.730. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 1945.593 s. Mean Reward: 3.758. Std of Reward: 1.829. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1800000. Time Elapsed: 1945.593 s. Mean Reward: 3.758. Std of Reward: 1.829. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1799971.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1799971.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 1999.530 s. Mean Reward: 3.799. Std of Reward: 1.905. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1850000. Time Elapsed: 1999.530 s. Mean Reward: 3.799. Std of Reward: 1.905. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 2055.492 s. Mean Reward: 3.914. Std of Reward: 1.892. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1900000. Time Elapsed: 2055.492 s. Mean Reward: 3.914. Std of Reward: 1.892. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 2107.833 s. Mean Reward: 3.840. Std of Reward: 1.861. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 1950000. Time Elapsed: 2107.833 s. Mean Reward: 3.840. Std of Reward: 1.861. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 2163.386 s. Mean Reward: 3.822. Std of Reward: 1.889. Training.
# INFO:mlagents.trainers.stats:Huggy. Step: 2000000. Time Elapsed: 2163.386 s. Mean Reward: 3.822. Std of Reward: 1.889. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1999995.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-1999995.onnx
# [INFO] Exported results/Huggy/Huggy/Huggy-2000068.onnx
# INFO:mlagents.trainers.torch.model_serialization:Exported results/Huggy/Huggy/Huggy-2000068.onnx
# [INFO] Copied results/Huggy/Huggy/Huggy-2000068.onnx to results/Huggy/Huggy.onnx.
# INFO:mlagents.trainers.model_saver.torch_model_saver:Copied results/Huggy/Huggy/Huggy-2000068.onnx to results/Huggy/Huggy.onnx.

# %% [markdown]
# ## Push the agent to the 🤗 Hub
#
# - Now that we trained our agent, we’re **ready to push it to the Hub to be able to play with Huggy on your browser🔥.**

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# Then, we simply need to run `mlagents-push-to-hf`.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/mlpush.png" alt="ml learn function" width="100%">

# %% [markdown]
# And we define 4 parameters:
#
# 1. `--run-id`: the name of the training run id.
# 2. `--local-dir`: where the agent was saved, it’s results/<run_id name>, so in my case results/First Training.
# 3. `--repo-id`: the name of the Hugging Face repo you want to create or update. It’s always <your huggingface username>/<the repo name>
# If the repo does not exist **it will be created automatically**
# 4. `--commit-message`: since HF repos are git repository you need to define a commit message.

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="vonewman/ppo-Huggy" --commit-message="Huggy"
# Out:
# HuggyTraining
# vonewman/ppo-Huggy
# This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  ppo-Huggy
# ORGANIZATION:  vonewman
# Cloning https://huggingface.co/vonewman/ppo-Huggy into local empty directory.
# Upload file Huggy/Huggy-1999995.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
# Upload file Huggy/Huggy-999928.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
# Upload file Huggy/Huggy-1199984.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
# Upload file Huggy/Huggy-1999995.pt:   2% 320k/12.9M [00:01<00:44, 294kB/s]
#
#
#
# Upload file Huggy/Huggy-599969.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
# Upload file Huggy/Huggy-599969.pt:   5% 704k/12.9M [00:01<00:18, 686kB/s]
# Upload file Huggy/Huggy-999928.pt:   7% 864k/12.9M [00:01<00:14, 849kB/s]
#
# Upload file Huggy/Huggy-1199984.pt:   6% 832k/12.9M [00:01<00:15, 816kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt:   6% 800k/12.9M [00:01<00:16, 784kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1999995.pt:  26% 3.38M/12.9M [00:02<00:04, 2.00MB/s]
#
#
# Upload file Huggy/Huggy-399986.pt:   6% 800k/12.9M [00:01<00:16, 783kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt:   6% 736k/12.9M [00:01<00:17, 719kB/s]
#
#
# Upload file Huggy/Huggy-1999995.pt:  51% 6.56M/12.9M [00:03<00:02, 2.61MB/s]
# Upload file Huggy/Huggy-999928.pt:  25% 3.19M/12.9M [00:02<00:05, 1.79MB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt:  23% 3.00M/12.9M [00:02<00:06, 1.70MB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt:  25% 3.16M/12.9M [00:02<00:05, 1.80MB/s]
#
#
#
# Upload file Huggy/Huggy-599969.pt:  24% 3.12M/12.9M [00:02<00:05, 1.78MB/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt:  23% 2.97M/12.9M [00:02<00:06, 1.67MB/s]
#
# Upload file Huggy/Huggy-1199984.pt:  25% 3.16M/12.9M [00:02<00:05, 1.77MB/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt:  42% 5.44M/12.9M [00:03<00:03, 2.08MB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt:  43% 5.59M/12.9M [00:03<00:03, 2.16MB/s]
#
#
#
# Upload file Huggy/Huggy-1999995.pt:  71% 9.16M/12.9M [00:04<00:01, 2.65MB/s]
#
#
# Upload file Huggy/Huggy-399986.pt:  46% 5.88M/12.9M [00:03<00:03, 2.26MB/s]
#
# Upload file Huggy/Huggy-1199984.pt:  44% 5.69M/12.9M [00:03<00:03, 2.17MB/s]
# Upload file Huggy/Huggy-999928.pt:  44% 5.72M/12.9M [00:03<00:03, 2.18MB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt:  44% 5.66M/12.9M [00:03<00:03, 2.17MB/s]
#
# Upload file Huggy/Huggy-1199984.pt:  64% 8.19M/12.9M [00:04<00:02, 2.34MB/s]
# Upload file Huggy/Huggy-1999995.pt:  91% 11.8M/12.9M [00:05<00:00, 2.67MB/s]
#
#
# Upload file Huggy/Huggy-399986.pt:  66% 8.53M/12.9M [00:04<00:01, 2.46MB/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt:  63% 8.09M/12.9M [00:04<00:02, 2.35MB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt:  63% 8.12M/12.9M [00:04<00:02, 2.35MB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt:  63% 8.09M/12.9M [00:04<00:02, 2.32MB/s]
#
#
#
# Upload file Huggy/Huggy-599969.pt:  65% 8.41M/12.9M [00:04<00:01, 2.44MB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt:  83% 10.7M/12.9M [00:05<00:00, 2.47MB/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt:  83% 10.8M/12.9M [00:05<00:00, 2.51MB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt:   1% 96.0k/12.9M [00:01<03:24, 65.4kB/s]
#
#
#
# Upload file Huggy/Huggy-599969.pt:  86% 11.1M/12.9M [00:05<00:00, 2.56MB/s]
# Upload file Huggy/Huggy-999928.pt:  85% 10.9M/12.9M [00:05<00:00, 2.52MB/s]
#
# Upload file Huggy/Huggy-1199984.pt:  83% 10.8M/12.9M [00:05<00:00, 2.46MB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt:  84% 10.8M/12.9M [00:05<00:00, 2.49MB/s]
#
#
# Upload file Huggy/Huggy-399986.pt:  87% 11.2M/12.9M [00:05<00:00, 2.59MB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt:  26% 3.31M/12.9M [00:02<00:04, 2.01MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000068.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.pt:   0% 32.0k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000068.pt:  21% 2.72M/12.9M [00:01<00:03, 2.81MB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.pt:  20% 2.56M/12.9M [00:01<00:04, 2.65MB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt:  63% 8.09M/12.9M [00:03<00:01, 3.37MB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399986.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999995.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599969.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt:  91% 11.7M/12.9M [00:04<00:00, 3.52MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000068.pt:  49% 6.25M/12.9M [00:02<00:02, 3.33MB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.pt:  48% 6.12M/12.9M [00:02<00:02, 3.28MB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.onnx:  23% 512k/2.17M [00:01<00:03, 490kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399986.onnx:  23% 512k/2.17M [00:01<00:03, 490kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999995.onnx:  25% 544k/2.17M [00:01<00:03, 523kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599969.onnx:  14% 320k/2.17M [00:01<00:06, 294kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799912.onnx:   1% 32.0k/2.17M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.onnx:  92% 2.00M/2.17M [00:01<00:00, 2.06MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000068.pt:  74% 9.53M/12.9M [00:03<00:01, 3.37MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599969.onnx:  92% 2.00M/2.17M [00:02<00:00, 1.16MB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.pt:  73% 9.44M/12.9M [00:03<00:01, 3.36MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799912.onnx:  13% 288k/2.17M [00:01<00:07, 262kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/vonewman/ppo-Huggy
#    e4ba58b..95810b6  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/vonewman/ppo-Huggy
#    e4ba58b..95810b6  main -> main
#
# Upload file Huggy/Huggy-1999995.pt: 100% 12.9M/12.9M [00:12<00:00, 712kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999995.pt: 100% 12.9M/12.9M [00:12<00:00, 1.12MB/s]
#
# Upload file Huggy/Huggy-999928.pt: 100% 12.9M/12.9M [00:11<00:00, 872kB/s]
# Upload file Huggy/Huggy-999928.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
# Upload file Huggy/Huggy-1199984.pt: 100% 12.9M/12.9M [00:11<00:00, 883kB/s]
#
# Upload file Huggy/Huggy-1199984.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
# Upload file Huggy/Huggy-399986.pt: 100% 12.9M/12.9M [00:11<00:00, 852kB/s]
#
#
# Upload file Huggy/Huggy-399986.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
#
# Upload file Huggy/Huggy-599969.pt: 100% 12.9M/12.9M [00:11<00:00, 866kB/s]
#
#
#
# Upload file Huggy/Huggy-599969.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-799912.pt: 100% 12.9M/12.9M [00:11<00:00, 893kB/s]
#
#
#
#
# Upload file Huggy/Huggy-799912.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt: 100% 12.9M/12.9M [00:11<00:00, 886kB/s]
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt: 100% 12.9M/12.9M [00:11<00:00, 892kB/s]
#
#
#
#
#
#
# Upload file Huggy/Huggy-1399916.pt: 100% 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt: 100% 12.9M/12.9M [00:07<00:00, 1.57MB/s]
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.pt: 100% 12.9M/12.9M [00:07<00:00, 1.92MB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000068.pt: 100% 12.9M/12.9M [00:05<00:00, 2.45MB/s]
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-2000068.pt: 100% 12.9M/12.9M [00:05<00:00, 2.68MB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.pt: 100% 12.9M/12.9M [00:05<00:00, 2.48MB/s]
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.pt: 100% 12.9M/12.9M [00:05<00:00, 2.68MB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx: 100% 2.17M/2.17M [00:05<00:00, 446kB/s]
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy.onnx: 100% 2.17M/2.17M [00:05<00:00, 446kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.onnx: 100% 2.17M/2.17M [00:04<00:00, 563kB/s]
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-199979.onnx: 100% 2.17M/2.17M [00:04<00:00, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399986.onnx: 100% 2.17M/2.17M [00:04<00:00, 563kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-399986.onnx: 100% 2.17M/2.17M [00:04<00:00, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999995.onnx: 100% 2.17M/2.17M [00:04<00:00, 560kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1999995.onnx: 100% 2.17M/2.17M [00:04<00:00, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.onnx: 100% 2.17M/2.17M [00:04<00:00, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1799971.onnx: 100% 2.17M/2.17M [00:04<00:00, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599969.onnx: 100% 2.17M/2.17M [00:04<00:00, 486kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-599969.onnx: 100% 2.17M/2.17M [00:04<00:00, 557kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-1599997.onnx: 100% 2.17M/2.17M [00:03<00:00, 743kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799912.onnx: 100% 2.17M/2.17M [00:03<00:00, 797kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upload file Huggy/Huggy-799912.onnx: 100% 2.17M/2.17M [00:03<00:00, 743kB/s]
# Upload file Huggy/Huggy-1399916.onnx: 100% 2.17M/2.17M [00:02<00:00, 1.11MB/s]
#
# Upload file Huggy/Huggy-999928.onnx: 100% 2.17M/2.17M [00:02<00:00, 1.11MB/s]
#
#
# Upload file Huggy/Huggy-1199984.onnx: 100% 2.17M/2.17M [00:02<00:00, 959kB/s]
#
# Upload file Huggy/Huggy-1199984.onnx: 100% 2.17M/2.17M [00:02<00:00, 1.11MB/s]
#
#
#
# Upload file Huggy/events.out.tfevents.1674049099.488150a49770.11346.0: 100% 397k/397k [00:02<00:00, 186kB/s]
#
#
# Upload file Huggy/events.out.tfevents.1674049099.488150a49770.11346.0: 100% 397k/397k [00:02<00:00, 186kB/s]
#
#  Your model is pushed to the hub. You can view your model here: https://huggingface.co/vonewman/ppo-Huggy

# %% [markdown]
# ## Play with your Huggy 🐕
#
# This step is the simplest:
#
# - Open the game Huggy in your browser: https://singularite.itch.io/huggy
#
# - Click on Play with my Huggy model
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit-bonus1/load-huggy.jpg" alt="load-huggy" width="100%">
